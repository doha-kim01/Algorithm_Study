# %%
#Week1
#김상연

#1주차 백준 알고리즘 01 (18108번)
y = int(input( ))
print(y - 543)


#1주차 백준 알고리즘 02 (14681번)
x = int(input())
y = int(input())

if (x > 0 and y > 0) :
    print("1")
    
elif (x < 0 and y > 0) :
    print("2")
    
elif (x < 0 and y < 0):
    print("3")

elif (x > 0 and y < 0):
    print("4")


# 1주차 백준 알고리즘 03 (11021번)
T = int(input())

for i in range(1, T + 1, 1) :
    A, B = map(int, input().split(" "))
    str = "Case #{0}: {1}".format(i, A + B)
    print(str)

  
# 1주차 백준 알고리즘 04(10818번)
a = int(input())

list_a =  list( map(int, input().split(" ")) )

mini = list_a[0]
MAX = list_a[0]

for i in range (0, len(list_a), 1) :
    if (list_a[i] < mini) :
        mini = list_a[i]
    
    if (list_a[i] > MAX) :
        MAX = list_a[i]

print(mini, MAX)


# Week2
#  05(15596번)
def solve(a) :
    ans = 0
    for i in a :
        ans += i
        
    return ans


# 06(1157번)
message = input()
message = message.upper()

arr = list( range(0, len(message)) )
i = 0

for index in message :
    arr[i] = index
    i += 1

array = list( range(0, 26) ) # 0 ~25번 인덱스를 각각의 숫자로 리스트 만들기
array =  [0 for i in range (26)] # 모든 원소 0으로 초기화

for i in range (0, len(arr), 1) :
    array [ord(arr[i]) - 65] += 1

for i in range (0, len(array), 1) :
    print( i, ":", array[i])

cnt = 0
value = 0

for i in range (0, 26, 1) :
    if (cnt < array[i]) :
        cnt = array[i]
        value = i
    
    elif (cnt == array[i]) :
        value = -2
    print("i :", i, "cnt :", cnt, "value :", value)

print(chr(value + 65))


# 07(2775번)



# 08(2581번)
M = int(input())
N = int(input())

list_a = [ ]

for i in range (M, N + 1, 1) :
    flag = 0
    if (i > 1) :
        for j in range (2, i, 1) :
            if (i % j == 0) :
                flag += 1
                break
        
        if (flag == 0) :
            list_a.append(i)
        
        
if ( len(list_a) > 0) :
    print(sum(list_a))
    print(min(list_a))

else :
    print(-1)
  

# 09 (25305번)
N, k = map(int, input().split(" "))
score_list = list(map(int, input().split(" ")))

score_list.sort(reverse = True)

print(score_list[k - 1])


#10 (10872번)
def factorial(n) :
    if (n == 0) :
        return 1
    else :
        return n * factorial(n - 1)
        
a = int(input())
print(factorial(a))


#11 (2798번)
from itertools import combinations

N, M = map(int, input().split(" "))
card_list = list(map(int, input().split(" ")))
result_max = 0

for card in combinations(card_list, 3) :
    result = sum(card)
    if (result <= M) :
        if (result_max < result) :
            result_max = result
            
print(result_max)


#12 (10815번)
N = int(input())
my_list = list(map(int, input().split(" ")))

M = int(input())
number_list = list(map(int, input().split(" ")))

result_list = [0 for i in range (M)]

for i in range (0, M, 1) :
    for j in range (0, N, 1) :
        if (number_list[i] == my_list[j]) :
            result_list[i] = 1

for num in result_list:
    print(num, end = ' ')


# 10828번
import sys

N = int(input())
stack = []

for i in range (0, N, 1) :
    msg = list(sys.stdin.readline().split())
    
    if (msg[0] == 'push') :
        stack.append(int(msg[1]))
        
    elif (msg[0] == 'pop') :
        if not stack :
            print(-1)
        else :
            num = stack.pop()
            print(num)
            
    elif (msg[0] == 'size'):
        print(len(stack))
        
    elif (msg[0] == 'empty') :
        if not stack:
            print (1)
        else :
            print (0)
        
    elif (msg[0] == 'top') :
        if not stack:
            print(-1)
        else:
            print(stack[-1])


# 9093번
import sys

N = int(input())


for i in range (0, N, 1) :
    order = list(sys.stdin.readline().split())
    
    for j in range (0, len(order), 1) :
        result = list(order[j])
        result.reverse()
        answer = ''.join(result)
        print(answer, end = ' ')


# 1158번
N, K = map(int, input().split(" "))

number = []
die = []

for i in range (0, N, 1) :
    number.append(i+1)
    
while (len(number) != 0) :
    if (len(number) < K):
        while (len(number) != 0) :
            result = number.pop(0)
            die.append(result)
            
    else:
        result = number.pop(K - 1)
        die.append(result)
    
        for j in range (0, K - 1, 1):
            a =  number.pop(0)
            number.append(a)

print("<", end = "")

for i in range (0, len(die), 1) :
    if (i == len(die) - 1):
        print("{0}".format(die[i]), end = "")
    else :
        print("{0}, ".format(die[i]), end = "")
        
print(">")


#Week5
#1676번

def fact(n) :
    value = 1
    if (n != 1) : 
        for i in range (2, n+1, 1) :
            value *= i 
    return value

N = int(input())

msg = str(fact(N))
cnt = 0

for i in range (len(msg)-1, -1, -1):
    if ( msg[i] == '0' ):
        cnt += 1
    else:
        break

print(cnt)

# 1978번 소수 찾기

N = int(input())
nlist = list(map(int, input().split(" ")))

cnt = 0

for i in range (0, N, 1) :
    if (nlist[i] == 1) :
        continue
    if (nlist[i] == 2) :
        cnt = cnt + 1
        continue

    for j in range (2, nlist[i], 1) :
        if (nlist[i] % j == 0) :
            break
        if (j == nlist[i] - 1) :
            cnt = cnt + 1
            
print(cnt)


#1373번

n = int(input(), 2)
k = str(oct(n))

print(k[2:])

# %%
#김도하
#Week1
#18108
while (True):
  y = int(input())
  if (1000 <= y) and (y <= 3000):
    print(y-543)
    break

#14681
while(True):
  x = int(input())
  y = int(input())
  if x*y > 0:
    if y > 0:
      print(1)
    else :
      print(3)
  if x*y < 0:
    if y > 0:
      print(2)
    else :
      print(4)
  if(-1000 <= x and x <= 1000 and x != 0) and (-1000 <= y and y <= 1000 and y != 0):
    break

#11021
T = int(input())
for i in range(T):
    a,b = map(int, input().split())
    ans = a + b
    print("Case #%s: %s"%(i+1, ans ))

#10818
N = int(input())
n_list = list(map(int, input().split(" ")))
result = []
for i in range(N):
  a = int(n_list[i])
  result.append(a)

result.sort()
print(result[0],result[-1])

#Week2
#15596
def solve(a):
  sum = 0
  for i in a:
    sum = sum + i
  return sum
a = [1,2,3,4,5]
solve(a)

#1157
word = input().upper()
word_list = list(set(word))

cnt = []
for i in word_list:
  count = word.count
  cnt.append(count(i))

if cnt.count(max(cnt)) > 1:
  print("?")
else:
  print(word_list[(cnt.index(max(cnt)))])

#2775
T = int(input())

for _ in range(T):
  floor = int(input())
  rn = int(input())
  pp = [i for i in range(1, rn+1)]

  for _ in range(floor):
    for l in range(1,rn):
      pp[l] += pp[l-1]
  print(pp[-1])

#2581
M = int(input())
N = int(input())
prime = []
for i in range(M, N+1):
    if i != 1:
        check = True
        for j in range(2, i):
            if i % j == 0:
                check = False
                break
        if check:
            prime.append(i)
if len(prime) == 0:
    print(-1)
else:
    print(sum(prime))
    print(prime[0])

#Week3
#25305
# map은 리스트의 요소를 지정된 함수로 처리해주는 함수
# 원본 리스트를 변경하지 않고 새 리스트를 생성
n, k = map(int, input().split(" "))
score_list = list(map(int, input().split(" ")))
result = sorted(score_list, reverse = True)
print(result[k-1])

#10872
N = int(input())
def fac(N):
  if (N == 0):
    return 1
  else :
    return N * fac(N-1)

print(fac(N))

#2798
#Brute Force : 가능한 모든 경우를 시도하여, 원하는 답을 찾아내는 알고리즘
#전체 case들을 하나하나 탐색하면서, 문제 조건에 부합하는지 판단
n, m = map(int, input().split(" "))
card_list = list(map(int, input().split(" ")))
sum = 0
max = 0

for i in range(len(card_list)):
  for j in range(i+1, len(card_list)):
    for k in range(j+1, len(card_list)):
      sum = card_list[i] + card_list[j] + card_list[k]
      if (sum > m):
        continue
      elif max <= sum:
        max = sum
print(max)

#10815 - 시간초과
N = int(input())
card = list(map(int, input().split(" ")))
M = int(input())
is_card = list(map(int, input().split(" ")))

for i in range(M):
  if is_card[i] in card:
    is_card[i] = 1
  else:
    is_card[i] = 0
print(is_card)

#이것도 시간초과
result = []
for i in range(M):
  if is_card[i] in card:
    result.append(1)
  else:
    result.append(0)
print(result)


#Week4
#10828
# _ : underscore
# interpreter에서 마지막 값을 저장할 때
# 값을 무시하고 싶을 때
# 변수나 함수명에 특별한 의미 또는 기능을 부여하고자 할 때 
# 숫자 리터럴값의 자릿수 구분을 위한 구분자로써 사용할 때 
# sys.stdin.readline() : 반복문으로 여러 줄을 입력받을 때 
import sys
n = int(sys.stdin.readline())

stack=[]
for i in range(n):
    command = sys.stdin.readline().split()

    if command[0]=='push':
        stack.append(command[1])
    elif command[0]=='pop':
        if len(stack)==0:
            print(-1)
        else:
            print(stack.pop())
    elif command[0] == 'size':
        print(len(stack))
    elif command[0] == 'empty':
        if len(stack)==0:
            print(1)
        else:
            print(0)
    elif command[0] == 'top':
        if len(stack)==0:
            print(-1)
        else:
            print(stack[-1])

#9093
#stack 자료 구조를 이용한 풀이
T = int(input())
for i in range(T):
  string = input()
  string += " "
  stack = []
  for j in string:
    if j != " ":
      stack.append(j)
    else:
      while stack:
        print(stack.pop(), end = ' ')
      print(' ', end = '')

#리스트 내부에서 제공하는 기능을 이용한 풀이
T = int(input())

for i in range(T):
  string = list(input().split())
  for j in string:
    print(j[::-1], end = ' ')

#1158
from collections import deque

n, k = map(int, input().split())

# 1~n번 사람
people = deque()
for i in range(1, n+1): people.append(i)
result = []

while people:
  for _ in range(k-1):
    people.append(people.popleft())

  result.append(people.popleft())

print(str(result).replace('[', '<').replace(']', '>'))

# %%
#명승희

#10818
N = int(input())

list_N = list(map(int, input().split(" ")))
min = list_N[0]
max = list_N[0]

for i in range(N):
    if (list_N[i] <= min):
        min = list_N[i]
    elif(list_N[i] > max):
        max = list_N[i]
        
print(min, max)

#11021
T = int(input())

for i in range(1, T+1):
    A, B = map(int, input().split(" "))
    print("Case #%d: %d" %(i,A+B))

#14681
x = int(input())
y = int(input())

if x > 0 :
    if y > 0 :
        print(1)
    elif y < 0 :
        print(4)

if x < 0 :
    if y < 0 :
        print(3)
    elif y > 0 :
        print(2)

#18108
budda = int(input())

print(budda-543)

#2주차
#15596
def solve(a):
    return sum(a)

#1157
origin = input().upper() #입력받아 대문자로 mississipi -> MISSISSIPI
origin_list = list(set(origin)) #중복제거 후 다시 리스트로 I M S P

a = [] #문자의 횟수 넣어줄 리스트 선언함

for i in origin_list:
    count = origin.count(i) #문자들의 숫자 셌음
    a.append(count) #쪼개서 리스트에 넣음

if a.count(max(a)) >= 2: #a 리스트의 최댓값(제일 많이 나온 문자)이 여러개면 띠용?
    print("?")
else:
    print(origin_list[a.index(max(a))])

#2775
t = int(input())

for _ in range(t):  
    floor = int(input())  # 층
    num = int(input())  # 호
    f0 = [x for x in range(1, num+1)]  # 0층 리스트
    for k in range(floor):  # 층 수 만큼 반복
        for i in range(1, num):  # 1 ~ n-1까지 (인덱스로 사용)
            f0[i] += f0[i-1]  # 층별 각 호실의 사람 수를 변경
    print(f0[-1])

#2581
start_num = int(input())
last_num = int(input())

prime_list = []
for num in range(start_num, last_num+1):
    error = 0
    if num > 1 :
        for i in range(2, num):  # 2부터 num-1까지
            if num % i == 0:
                error += 1
                break  # 2부터 num-1까지 나눈 몫이 0이면 error가 증가하고 for문을 끝냄
        if error == 0:
            sosu_list.append(num)  # error가 없으면 소수리스트에 추가
            
if len(prime_list) > 0 :
    print(sum(prime_list))
    print(min(prime_list))
else:
    print(-1)

#3주차
#25305
n, k = map(int, input().split(" "))

score_list = list(map(int, input().split(" ")))

for i in range (1,n):
    for j in range (0, n-1):
        if score_list[j] < score_list[j+1]:
            score_list[j+1], score_list[j] = score_list[j], score_list[j+1]

print(score_list[k-1])

#10872
def factorial(n):
    result = 1
    if n > 0 :
        result = n * factorial(n-1)
    return result

n = int(input())
print(factorial(n))
//------------------------------
def fac(N):
    if N == 1:
        return 1
    else:
        return N*fac(N-1)
    
N = int(input())
print(fac(N)) //백준에서는 오류가 뜨지만 GDB에서는 작동하는 제 코드입니다 차이는 잘 모르겠어요

#2798
N, M = map(int, input().split(" "))

result = 0

card_list = list(map(int, input().split(" ")))

for i in range (0, N-2):
    for j in range (i+1, N-1):
        for k in range (j+1, N):
            if card_list[i]+card_list[j]+card_list[k] <= M:
                if card_list[i]+card_list[j]+card_list[k] > result:
                    result = card_list[i]+card_list[j]+card_list[k]

print(result)

#10815
N = int(input())
N_set = set(map(int, input().split(" ")))

M = int(input())
M_list = list(map(int, input().split(" ")))

for i in M_list:
    if i in N_set:
        print(1, end=' ')
    else:
        print(0, end=' ')

#4주차
#10828
import sys
N = int(sys.stdin.readline())

stack=[]
for _ in range(N):
    command = sys.stdin.readline().split()
    
    if(command[0] == "push"):
        stack.append(command[1])
        
    if(command[0] == "pop"):
        if(len(stack) == 0):
            print(-1)
        else:
            print(stack[-1])
            del(stack[-1])
    
    if(command[0] == "size"):
        print(len(stack))
        
    if(command[0] == "empty"):
        if(len(stack) == 0):
            print(1)
        else:
            print(0)
        
    if(command[0] == "top"):
        if(len(stack) == 0):
            print(-1)
        else:
            print(stack[-1])

#9093
import sys
 
n = int(sys.stdin.readline())
 
for _ in range(n):
  sentence = sys.stdin.readline().rstrip().split()
 
  for word in sentence:
    print(word[::-1], end=' ')
  print()

#1158
N, K = map(int, input().split(" "))

list = [j+1 for j in range(N)]

K -= 1
i = 0
ans = []

while len(list)!= 0:
    i = (i+K)%N
    ans.append(str(list[i]))
    del list[i]
    N -= 1

print("<",", ".join(ans)[:],">", sep='')

#5주차
#1978
N = int(input())

PrimeNum = list(map(int, input().split(" ")))
HowManyPrime = 0

def IsItPrime(n):
    dividend = 0
    if n == 1:
        return False
    elif n == 2:
        return True
    for i in range (2, n):
        if n % i == 0:
            return False
    return True

for i in PrimeNum:
    if IsItPrime(i):
        HowManyPrime += 1

print(HowManyPrime)

#1676
n = int(input())
HowManybeforeNum = 0

def factorial(n):
    result = 1
    if n > 0 :
        result = n * factorial(n-1)
    return result

result = str(factorial(n))

for i in result[::-1]:
    if i != '0':
        break
    HowManybeforeNum += 1

print(HowManybeforeNum)

#1373
Binary = int(input(),2)

print(oct(Binary)[2:])

# %%
#문원정
#18108
y=int(input())
print(y-543)

#14681
x=int(input())
y=int(input())
if x>0:
    if y>0:
        print('1')
    else:
        print('4')
else:
    if y>0:
        print('2')
    else:
        print('3')

#10818
import sys

N=int(sys.stdin.readline())
List=list(map(int, sys.stdin.readline().split()))

print(min(List))
print(max(List))

#11021
n=int(input())
for i in range(n):
    a,b=map(int, input().split())
    print("Case #"+str(i+1)+':',a+b)


#Week2
#15596 - c++
long long sum(int *a, int n)
{
    long long sum=0;
    int i;
    for(i=0;i<n;i++){
        sum+=a[i];
    }
    return sum;
}

#1157
word = input().upper()
word_list = list(set(word)) 
cnt_list = []
for i in word_list:
    cnt = word.count(i)
    cnt_list.append(cnt)  

if cnt_list.count(max(cnt_list)) > 1 :
    print('?')
else:
    print(word_list[cnt_list.index(max(cnt_list))])


#2775
T = int(input())

for i in range(T):
    
    k = int(input())
    n = int(input())
    people = []
    for j in range(n):
        people.append(j + 1)
        
    for a in range(k):
        cnt = 0
        for b in range(n):
            cnt += people[b]
            people[b] = cnt
            
    print(people[n - 1])


#2581
start = int(input())
last = int(input())

prime = []
for num in range(start, last+1):
    error = 0
    if num > 1 :
        for i in range(2, num):
            if num % i == 0:
                error += 1
                break
        if error == 0:
            prime.append(num)
            
if len(prime) > 0 :
    print(sum(prime))
    print(min(prime))
else:
    print(-1)

#3주차

#25305
n, k = map(int, input().split())
score = sorted(map(int, input().split()))
print(score[-k])    

#10872 (C++)
#include <stdio.h>
int factorial(int n){
	if (n <=1 ) {
		return 1;
	}
	else {	
		return n*factorial((n-1));
	}
}
    
int main(){
    int n;
    scanf("%d", &n);
    printf("%d\n", factorial(n));
    return 0;
}

#2798
n, m = map(int, input().split())
card = list(map(int, input().split()))
s_card=list()
for i in range(0,n-2):
    for j in range (i+1,n-1):
        for k in range (j+1,n):
            if ((card[i]!=card[j]!=card[k])==True) and card[i]+card[j]+card[k]<=m:
                s_card.append(card[i]+card[j]+card[k])
print(max(s_card))

#10815
import sys
input = sys.stdin.readline

N = int(input())
cards = list(map(int, input().split()))
dictionary = {card: 1 for card in cards}
M = int(input())
targets = list(map(int, input().split()))

for target in targets:
    if dictionary.get(target, 0):
        print(1, end=' ')
    else:
        print(0, end=' ')

#Week4

#10828
import sys
input=sys.stdin.readline

n = int(input()) 
stack=[]

for i in range(n):
    temp=input().split()

    if temp[0]=='push':
        stack.append(temp[1])
    elif temp[0]=='pop':
        if stack:
            print(stack.pop())
        else:
            print(-1)
    elif temp[0]=='top':
        if stack:
            print(stack[-1])
        else:
            print(-1)
    elif temp[0]=='size':
        print(len(stack))
    elif temp[0]=='empty':
        if stack:
            print(0)
        else:
            print(1)

 #9093
import sys

n = int(sys.stdin.readline())

for _ in range(n):
    s = sys.stdin.readline().split()
    stack = []

    for i in s:
        stack.append(i[::-1])
        
    print(*stack)

#1158
import sys

n, k = map(int, sys.stdin.readline().split())
stack = [i for i in range(1, n + 1)]
answer = []
cnt = k - 1

while stack:
    if cnt < len(stack):
        answer.append(stack.pop(cnt))
        cnt += k - 1

    else:
        cnt %= len(stack)

print("<", ", ".join(str(i) for i in answer), ">", sep="")

#Week5

#1978 (c)
#include <stdio.h>

int main(void)
{
    int N, num, i, j, count = 0;

    scanf("%d", &N);

    for (i = 0; i < N; i++)
    {
        scanf("%d", &num);

        for (j = 2; j <= num; j++)
        {
            if (num == j)
                count++;
            if (num % j == 0)
                break;
        }
    }

    printf("%d", count);

    return 0;
}

#1676 (c)
#include <stdio.h>
int main(void)
{
    int n, c=0;
    scanf("%d",&n);
    for(int i=2; i<=n; i++)
    {
        int ii=i;
        while (ii%5==0)
        {
            ii /= 5;
            c++;
        }
    }
    printf("%d",c);  
        
}

#1373
r = int(input(), 2)
print(oct(r)[2:])
